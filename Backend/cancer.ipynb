# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel(r'cancer patient data sets.xlsx')
df.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
df.tail()
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 995                     7             7                     6              7
# 996                     7             7                     6              7
# 997                     5             5                     4              6
# 998                     7             7                     6              7
# 999                     5             5                     4              6
#
#      ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
df.shape
# Out:
# (1000, 25)

# %%
df.dtypes
# Out:
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop('Patient Id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0        4  ...        3            4                    2         2
# ...

# %%
df["Level"].value_counts()
# Out:
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Level'] = le.fit_transform(df['Level'])

# %%
df["Level"].value_counts()
# Out:
# 0    365
# 2    332
# 1    303
# Name: Level, dtype: int64

# %% [markdown]
# High    -0
# Medium    -2
# Low       -1

# %%
x=df.drop('Level',axis=1)
x
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
y=df['Level']
y
# Out:
# 0      1
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Level, Length: 1000, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
x_train
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 423   44       1              2            3             2
# 157   42       1              2            4             5
# 670   37       1              7            7             7
# 256   25       2              3            1             4
# 965   48       2              1            6             7
# ..   ...     ...            ...          ...           ...
# 575   24       1              6            8             7
# 838   61       1              2            3             4
# 337   37       1              7            7             7
# 523   33       1              1            6             7
# 863   35       1              6            8             7
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 423                     1             3                     2              1
# 157                     6             5                     5              4
# ...

# %%
x_train.to_csv('final.csv')

# %%
y_train
# Out:
# 423    1
# 157    0
# 670    0
# 256    1
# 965    2
#       ..
# 575    0
# 838    1
# 337    0
# 523    2
# 863    2
# Name: Level, Length: 800, dtype: int32

# %%
x_test
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 545   44       1              1            2             3
# 298   23       1              3            2             4
# 109   25       2              4            5             6
# 837   62       1              3            2             1
# 194   36       2              2            1             5
# ..   ...     ...            ...          ...           ...
# 68    62       1              6            8             7
# 449   35       1              4            5             6
# 715   38       2              3            2             3
# 793   17       1              3            1             5
# 688   62       1              6            8             7
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 545                     4             2                     4              3
# 298                     2             3                     2              3
# ...

# %%
y_test
# Out:
# 545    2
# 298    2
# 109    0
# 837    1
# 194    2
#       ..
# 68     0
# 449    0
# 715    1
# 793    2
# 688    0
# Name: Level, Length: 200, dtype: int32

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier(n_estimators=52)
rf = rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier 
dt = DecisionTreeClassifier(criterion="entropy",max_depth=3)
dt = dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.915

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr = lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# C:\Users\ymts0591\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.99

# %%
abc=[44,	1,	2,	3,	2,	1,	3,	2,	1,	2,	7,	6,	2,	2,	2,	2,	3,	2,	1,	2,	3,	2,	3]
result=rf.predict([abc])
result=result[0]
if result==0:
    print("High")
elif result==1:
    print("Low")
else:
    print("Medium")
# Out:
# Low
# C:\Users\ymts0591\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
abc=[42,	1,	2,	4,	5,	6,	5,	5,	4,	6,	7,	7,	2,	3,	8,	7,	7,	3,	8,	9,	1,	6,	2]
result=rf.predict([abc])
result=result[0]
if result==0:
    print("High")
elif result==1:
    print("Low")
else:
    print("Medium")
# Out:
# High
# C:\Users\ymts0591\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
abc=[48,	2,	1,	6,	7,	8,	7,	6,	7,	7,	3,	4,	8,	7,	3,	2,	6,	4,	2,	3,	1,	2,	1]
result=rf.predict([abc])
result=result[0]
if result==0:
    print("High")
elif result==1:
    print("Low")
else:
    print("Medium")
# Out:
# Medium
# C:\Users\ymts0591\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
x_train.columns
# Out:
# Index(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring'],
#       dtype='object')
